# %% [markdown]
# # 1.5.4 Introduction to SIFT (Scale-Invariant Feature Transform)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('sources/ir.jpeg')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
#sift = cv2.SIFT()
sift = cv2.SIFT_create()
kp = sift.detect(gray,None)
imgsift = cv2.imread('sources/ir.jpeg')
imgsift=cv2.drawKeypoints(img,kp,imgsift,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
plt.figure(figsize = (30,45))
plt.subplot(1,2,1),plt.imshow(img,cmap = 'gray')
plt.title('img'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(imgsift,cmap = 'gray')
plt.title('imgsift'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # 1.5.5 Introduction to SURF (Speeded-Up Robust Features)

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2.3.0,>=2 in /Users/sochiru/development/study/school/2025/5-video-processing/.conda/lib/python3.11/site-packages (from opencv-python) (2.2.6)
# Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.12.0.88

# %%
# !python3 -m pip uninstall -y opencv-python opencv-python-headless opencv-contrib-python opencv-contrib-python-headless
# !python3 -m pip install opencv-contrib-python
# Out:
# Found existing installation: opencv-python 4.12.0.88
# Uninstalling opencv-python-4.12.0.88:
#   Successfully uninstalled opencv-python-4.12.0.88
# WARNING: Skipping opencv-python-headless as it is not installed.
# Found existing installation: opencv-contrib-python 4.12.0.88
# Uninstalling opencv-contrib-python-4.12.0.88:
#   Successfully uninstalled opencv-contrib-python-4.12.0.88
# WARNING: Skipping opencv-contrib-python-headless as it is not installed.
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2.3.0,>=2 in /Users/sochiru/development/study/school/2025/5-video-processing/.conda/lib/python3.11/site-packages (from opencv-contrib-python) (2.2.6)
# Using cached opencv_contrib_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (46.9 MB)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.12.0.88

# %%
img = cv2.imread('sources/ir.jpeg')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
#surf = cv2.SURF(400)
surf = cv2.xfeatures2d.SURF_create(400)
kp, des = surf.detectAndCompute(img,None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 #surf = cv2.SURF(400)
# ----> 2 surf = cv2.xfeatures2d.SURF_create(400)
#       3 kp, des = surf.detectAndCompute(img,None)
#
# AttributeError: module 'cv2.xfeatures2d' has no attribute 'SURF_create'

# %% [markdown]
# # 1.5.6 FAST Algorithm for Corner Detection

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('sources/ir.jpeg',0)

# %%
# Initiate FAST object with default values
fast = cv2.FastFeatureDetector()
# find and draw the keypoints
kp = fast.detect(img,None)
img2 = cv2.drawKeypoints(img, kp, color=(255,0,0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Initiate FAST object with default values
# ----> 2 fast = cv2.FastFeatureDetector()
#       3 # find and draw the keypoints
#       4 kp = fast.detect(img,None)
#
# NameError: name 'cv2' is not defined

# %%
# Print all default params
print "Threshold: ", fast.getInt('threshold')
print "nonmaxSuppression: ", fast.getBool('nonmaxSuppression')
print "neighborhood: ", fast.getInt('type')
print "Total Keypoints with nonmaxSuppression: ", len(kp)
cv2.imwrite('fast_true.png',img2)

# %%
# Disable nonmaxSuppression
fast.setBool('nonmaxSuppression',0)
kp = fast.detect(img,None)
print "Total Keypoints without nonmaxSuppression: ", len(kp)
img3 = cv2.drawKeypoints(img, kp, color=(255,0,0))
cv2.imwrite('fast_false.png',img3)

# %% [markdown]
# ## 1.5.7 BRIEF (Binary Robust Independent Elementary Features)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('sources/ir.jpeg',0)

# %%
# Initiate STAR detector
star = cv2.FeatureDetector_create("STAR")
# Initiate BRIEF extractor
brief = cv2.DescriptorExtractor_create("BRIEF")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e2ee5b8d83fe> in <module>
#       1 # Initiate STAR detector
# ----> 2 star = cv2.FeatureDetector_create("STAR")
#       3 # Initiate BRIEF extractor
#       4 brief = cv2.DescriptorExtractor_create("BRIEF")
#
# AttributeError: module 'cv2.cv2' has no attribute 'FeatureDetector_create'

# %%
# find the keypoints with STAR
kp = star.detect(img,None)
# compute the descriptors with BRIEF
kp, des = brief.compute(img, kp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ed783b7591ab> in <module>
#       1 # find the keypoints with STAR
# ----> 2 kp = star.detect(img,None)
#       3 # compute the descriptors with BRIEF
#       4 kp, des = brief.compute(img, kp)
#
# NameError: name 'star' is not defined

# %%
# Print all default params
print("Threshold: ", fast.getInt('threshold'))
print("nonmaxSuppression: ", fast.getBool('nonmaxSuppression'))
print("neighborhood: ", fast.getInt('type'))
print("Total Keypoints with nonmaxSuppression: ", len(kp))
cv2.imwrite('fast_true.png',img2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-be5ced19ac29> in <module>
#       1 # Print all default params
# ----> 2 print("Threshold: ", fast.getInt('threshold'))
#       3 print("nonmaxSuppression: ", fast.getBool('nonmaxSuppression'))
#       4 print("neighborhood: ", fast.getInt('type'))
#       5 print("Total Keypoints with nonmaxSuppression: ", len(kp))
#
# NameError: name 'fast' is not defined

# %%
# Disable nonmaxSuppression
fast.setBool('nonmaxSuppression',0)
kp = fast.detect(img,None)
print("Total Keypoints without nonmaxSuppression: ", len(kp))
img3 = cv2.drawKeypoints(img, kp, color=(255,0,0))
cv2.imwrite('fast_false.png',img3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e926e1dc75f1> in <module>
#       1 # Disable nonmaxSuppression
# ----> 2 fast.setBool('nonmaxSuppression',0)
#       3 kp = fast.detect(img,None)
#       4 print("Total Keypoints without nonmaxSuppression: ", len(kp))
#       5 img3 = cv2.drawKeypoints(img, kp, color=(255,0,0))
#
# NameError: name 'fast' is not defined

# %% [markdown]
# ## 1.5.8 ORB (Oriented FAST and Rotated BRIEF)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('sources/ir.jpeg',0)
# Initiate STAR detector
orb = cv2.ORB()

# %%
# find the keypoints with ORB
kp = orb.detect(img,None)
# compute the descriptors with ORB
kp, des = orb.compute(img, kp)
# draw only keypoints location,not size and orientation
img2 = cv2.drawKeypoints(img,kp,color=(0,255,0), flags=0)
plt.imshow(img2),plt.show()
